# %% [markdown]
# # Data Ingestion
#
# This notebook demonstrates the extraction and loading of raw mutual fund datasets used in the Bluestock Mutual Fund Analytics Capstone Project.
#
# Datasets:
# - NAV History
# - Scheme Performance
# - Investor Transactions
# - Benchmark Data

# %%
import pandas as pd

nav = pd.read_csv("../data/raw/nav_history.csv")
performance = pd.read_csv("../data/raw/scheme_performance.csv")
transactions = pd.read_csv("../data/raw/investor_transactions.csv")

print(nav.shape)
print(performance.shape)
print(transactions.shape)

# %% [markdown]
# Data was successfully loaded and prepared for cleaning and transformation.
